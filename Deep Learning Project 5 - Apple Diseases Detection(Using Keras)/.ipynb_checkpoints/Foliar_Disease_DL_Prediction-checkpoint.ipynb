# %% [markdown]
# # Foliar Disease in Apple

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import os
from re import search
import shutil
import natsort
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm
import cv2

# %% [markdown]
# ### Import Dataset

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-02b8226b-79e6-4f4d-b8b5-9c3a25cd86ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02b8226b-79e6-4f4d-b8b5-9c3a25cd86ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"thobelasixpence","key":"97e3bc65c43f113cf8eb0829dd22adf5"}'}

# %%
# create a kaggle directory
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# permission for json files to act
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c plant-pathology-2020-fgvc7
# Out:
# Downloading plant-pathology-2020-fgvc7.zip to /content
#  99% 769M/779M [00:30<00:00, 25.8MB/s]
# 100% 779M/779M [00:30<00:00, 27.1MB/s]

# %%
# !pip install zip_files
# Out:
# Collecting zip_files
#   Downloading zip_files-0.4.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from zip_files) (7.1.2)
# Installing collected packages: zip-files
# Successfully installed zip-files-0.4.1

# %%
from zipfile import ZipFile
# open the zipped file
file_name="plant-pathology-2020-fgvc7.zip"
with ZipFile(file_name,'r') as zip:
      zip.extractall()
      print('Done')
# Out:
# Done

# %% [markdown]
# ### Data Directory

# %%
# import the dataset for train(labels)
train=pd.read_csv("/content/train.csv")
# import the dataset for test(labels)
test=pd.read_csv("/content/test.csv")

# %%
# dirctory for pictures
data_dir = '/content/images'

# %%
train.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
test.head()
# Out:
#   image_id
# 0   Test_0
# 1   Test_1
# 2   Test_2
# 3   Test_3
# 4   Test_4

# %%
# get the first image just to verify
img_0 = Image.open('/content/images/Test_0.jpg')
plt.imshow(img_0)
plt.show()

# %% [markdown]
# ## Preparing Data

# %%
# get the columns from healthy down to the right
class_names = train.loc[:, 'healthy':].columns
print(class_names)
# Out:
# Index(['healthy', 'multiple_diseases', 'rust', 'scab'], dtype='object')

# %%
num = 0
train['label'] = 0
for i in class_names:
  train['label'] = train['label'] + train[i] * num
  num = num+1

# %%
print(num)
# Out:
# 4

# %%
train.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab  label
# 0  Train_0        0                  0     0     1      3
# 1  Train_1        0                  1     0     0      1
# 2  Train_2        1                  0     0     0      0
# 3  Train_3        0                  0     1     0      2
# 4  Train_4        1                  0     0     0      0

# %%
data_dir
# Out:
# '/content/images'

# %%
# naturally sort the directory
natsort.natsorted(os.listdir(data_dir))

# %%
# we want to get the label of the image since we have four labels which meanss four categories of flowers that our DL model needs to be trained
# on
def get_img_label(img):
  # search forr the string given
  if search("Train", img):
    #split the img and get the first pos
    img = img.split('.')[0]
    # get the labe for the img
    label = train.loc[train['image_id']==img]['label']
    return label

# %%
# now we gonna create data for ttraining with the correct categorie of classes found in labels
def create_train_dataset():
  # get all the images that are naturally sorted
  images = natsort.natsorted(os.listdir(data_dir))
  for img in tqdm(images):
    # get the label of the image
    label = get_img_label(img)
    # get path 
    path = os.path.join(data_dir, img)

    if search("Train", img):
      # split the image name because it is named like this image_1.jpg
      if(img.split('_')[1].split('.')[0]) and label.item()==0:
        shutil.copy(path,'/content/train/healthy')

      elif(img.split('_')[1].split('.')[0]) and label.item()==1:
        shutil.copy(path,'/content/train/multiple_diseases')

      elif(img.split('_')[1].split('.')[0]) and label.item()==2:
        shutil.copy(path,'/content/train/rust')

      elif(img.split('_')[1].split('.')[0]) and label.item()==3:
        shutil.copy(path,'/content/train/scab')

    if search("Test", img):
      shutil.copy(path,'/content/test')

# %%
shutil.os.mkdir(r'/content/train/')

shutil.os.mkdir(r'/content/train/healthy')
shutil.os.mkdir(r'/content/train/multiple_diseases')
shutil.os.mkdir(r'/content/train/rust')
shutil.os.mkdir(r'/content/train/scab')

shutil.os.mkdir(r'/content/test')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-43-abd1ab0ea400> in <module>()
# ----> 1 shutil.os.mkdir(r'/content/train')
#       2
#       3 shutil.os.mkdir(r'/content/train/healthy')
#       4 shutil.os.mkdir(r'/content/train/multiple_diseases')
#       5 shutil.os.mkdir(r'/content/train/rust')
#
# FileExistsError: [Errno 17] File exists: '/content/train'

# %%
train_dir=create_train_dataset()
# Out:
# 100%|██████████| 3642/3642 [00:03<00:00, 1157.16it/s]

# %% [markdown]
# ## Data Preprocessing

# %%
train_dir = r'/content/train'
train_dir
# Out:
# '/content/train'

# %%
#train_dir = r'Dataset\train'
# categories for classification
categories = ['healthy','multiple_diseases','rust','scab']
# join the path with the category 
for i in categories:
  path = os.path.join(train_dir, i)
  for img in os.listdir(path):
    old_img = cv2.imread(os.path.join(path, img), cv2.COLOR_BGR2RGB)
    plt.imshow(old_img)
    plt.show()
    break
  break

# %%
# show a resized image
img_size = 224
new_img = cv2.resize(old_img, (img_size, img_size))
plt.imshow(new_img)
plt.show()

# %% [markdown]
# # Model Preparation

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Activation,Flatten, Conv2D, MaxPooling2D

# %%
# generate data
datagen = ImageDataGenerator(rescale = 1./225,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             vertical_flip = True,
                             validation_split = 0.2)

train_datagen = datagen.flow_from_directory('/content/train',
                                            target_size = (img_size, img_size),
                                            batch_size = 16,
                                            class_mode = 'categorical',
                                            subset='training')

val_datagen = datagen.flow_from_directory('/content/train',
                                            target_size = (img_size, img_size),
                                            batch_size = 16,
                                            class_mode = 'categorical',
                                            subset='validation')
# Out:
# Found 1458 images belonging to 4 classes.
# Found 363 images belonging to 4 classes.

# %% [markdown]
# # Model Building

# %%
model= Sequential()
model.add(Conv2D(64, (3, 3), activation = 'relu', padding = 'same', input_shape = (img_size,img_size, 3)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3, 3), activation = 'relu', padding = 'same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3, 3), activation = 'relu', padding = 'same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(4, activation='softmax'))

# compiling model
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001),
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# check the model structure
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 224, 224, 64)      1792
#
#  max_pooling2d_8 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 112, 112, 64)      36928
#
#  max_pooling2d_9 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 4)                 100356
#
# =================================================================
# Total params: 249,860
# Trainable params: 249,860
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
checkpoint = ModelCheckpoint('apple_model.h5',
                             monitor = 'val_loss',
                             mode = 'min',
                             save_best_only = True,
                             verbose = 1)

earlystop= EarlyStopping(monitor = 'val_loss',
                          min_delta =0,
                          patience = 10,
                          verbose =1,
                          restore_best_weights=True)

callbacks = [checkpoint, earlystop]

# %%
model_history = model.fit_generator(train_datagen, 
                                    validation_data = val_datagen,
                                    epochs = 30,
                                    steps_per_epoch = train_datagen.samples//16,
                                    validation_steps = val_datagen.samples//16,
                                    callbacks = callbacks)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 91/91 [==============================] - ETA: 0s - loss: 1.2876 - accuracy: 0.3037
# Epoch 1: val_loss improved from inf to 1.23614, saving model to apple_model.h5
# 91/91 [==============================] - 74s 799ms/step - loss: 1.2876 - accuracy: 0.3037 - val_loss: 1.2361 - val_accuracy: 0.3381
# Epoch 2/30
# 91/91 [==============================] - ETA: 0s - loss: 1.2489 - accuracy: 0.3197
# Epoch 2: val_loss did not improve from 1.23614
# 91/91 [==============================] - 77s 853ms/step - loss: 1.2489 - accuracy: 0.3197 - val_loss: 1.2411 - val_accuracy: 0.3352
# Epoch 3/30
# 91/91 [==============================] - ETA: 0s - loss: 1.2394 - accuracy: 0.3738
# Epoch 3: val_loss did not improve from 1.23614
# 91/91 [==============================] - 71s 777ms/step - loss: 1.2394 - accuracy: 0.3738 - val_loss: 1.2389 - val_accuracy: 0.3352
# Epoch 4/30
# 91/91 [==============================] - ETA: 0s - loss: 1.0786 - accuracy: 0.4979
# Epoch 4: val_loss improved from 1.23614 to 0.90296, saving model to apple_model.h5
# 91/91 [==============================] - 71s 784ms/step - loss: 1.0786 - accuracy: 0.4979 - val_loss: 0.9030 - val_accuracy: 0.6420
# Epoch 5/30
# 91/91 [==============================] - ETA: 0s - loss: 0.7874 - accuracy: 0.6956
# Epoch 5: val_loss improved from 0.90296 to 0.70665, saving model to apple_model.h5
# 91/91 [==============================] - 71s 781ms/step - loss: 0.7874 - accuracy: 0.6956 - val_loss: 0.7067 - val_accuracy: 0.7074
# Epoch 6/30
# 91/91 [==============================] - ETA: 0s - loss: 0.7193 - accuracy: 0.7198
# Epoch 6: val_loss did not improve from 0.70665
# 91/91 [==============================] - 71s 784ms/step - loss: 0.7193 - accuracy: 0.7198 - val_loss: 0.7101 - val_accuracy: 0.7301
# Epoch 7/30
# 91/91 [==============================] - ETA: 0s - loss: 0.6830 - accuracy: 0.7337
# Epoch 7: val_loss improved from 0.70665 to 0.67017, saving model to apple_model.h5
# 91/91 [==============================] - 71s 784ms/step - loss: 0.6830 - accuracy: 0.7337 - val_loss: 0.6702 - val_accuracy: 0.7443
# Epoch 8/30
# 91/91 [==============================] - ETA: 0s - loss: 0.6765 - accuracy: 0.7393
# Epoch 8: val_loss improved from 0.67017 to 0.62266, saving model to apple_model.h5
# 91/91 [==============================] - 71s 783ms/step - loss: 0.6765 - accuracy: 0.7393 - val_loss: 0.6227 - val_accuracy: 0.7472
# Epoch 9/30
# 91/91 [==============================] - ETA: 0s - loss: 0.5926 - accuracy: 0.7663
# Epoch 9: val_loss did not improve from 0.62266
# 91/91 [==============================] - 71s 784ms/step - loss: 0.5926 - accuracy: 0.7663 - val_loss: 0.6344 - val_accuracy: 0.7500
# Epoch 10/30
# 91/91 [==============================] - ETA: 0s - loss: 0.5760 - accuracy: 0.7795
# Epoch 10: val_loss improved from 0.62266 to 0.52275, saving model to apple_model.h5
# 91/91 [==============================] - 71s 778ms/step - loss: 0.5760 - accuracy: 0.7795 - val_loss: 0.5228 - val_accuracy: 0.8182
# Epoch 11/30
# 91/91 [==============================] - ETA: 0s - loss: 0.5213 - accuracy: 0.8128
# Epoch 11: val_loss did not improve from 0.52275
# 91/91 [==============================] - 71s 781ms/step - loss: 0.5213 - accuracy: 0.8128 - val_loss: 0.5648 - val_accuracy: 0.8125
# Epoch 12/30
# 91/91 [==============================] - ETA: 0s - loss: 0.5091 - accuracy: 0.8280
# Epoch 12: val_loss improved from 0.52275 to 0.48282, saving model to apple_model.h5
# 91/91 [==============================] - 71s 783ms/step - loss: 0.5091 - accuracy: 0.8280 - val_loss: 0.4828 - val_accuracy: 0.8295
# Epoch 13/30
# 91/91 [==============================] - ETA: 0s - loss: 0.4816 - accuracy: 0.8287
# Epoch 13: val_loss did not improve from 0.48282
# 91/91 [==============================] - 77s 851ms/step - loss: 0.4816 - accuracy: 0.8287 - val_loss: 0.4954 - val_accuracy: 0.8040
# Epoch 14/30
# 91/91 [==============================] - ETA: 0s - loss: 0.4470 - accuracy: 0.8454
# Epoch 14: val_loss improved from 0.48282 to 0.41745, saving model to apple_model.h5
# 91/91 [==============================] - 71s 778ms/step - loss: 0.4470 - accuracy: 0.8454 - val_loss: 0.4175 - val_accuracy: 0.8551
# Epoch 15/30
# 91/91 [==============================] - ETA: 0s - loss: 0.4554 - accuracy: 0.8398
# Epoch 15: val_loss improved from 0.41745 to 0.34638, saving model to apple_model.h5
# 91/91 [==============================] - 71s 782ms/step - loss: 0.4554 - accuracy: 0.8398 - val_loss: 0.3464 - val_accuracy: 0.8920
# Epoch 16/30
# 91/91 [==============================] - ETA: 0s - loss: 0.3783 - accuracy: 0.8682
# Epoch 16: val_loss improved from 0.34638 to 0.33246, saving model to apple_model.h5
# 91/91 [==============================] - 71s 784ms/step - loss: 0.3783 - accuracy: 0.8682 - val_loss: 0.3325 - val_accuracy: 0.8722
# Epoch 17/30
# 91/91 [==============================] - ETA: 0s - loss: 0.3466 - accuracy: 0.8828
# Epoch 17: val_loss did not improve from 0.33246
# 91/91 [==============================] - 72s 788ms/step - loss: 0.3466 - accuracy: 0.8828 - val_loss: 0.3476 - val_accuracy: 0.8665
# Epoch 18/30
# 91/91 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.8953
# Epoch 18: val_loss did not improve from 0.33246
# 91/91 [==============================] - 71s 781ms/step - loss: 0.3174 - accuracy: 0.8953 - val_loss: 0.4304 - val_accuracy: 0.8722
# Epoch 19/30
# 91/91 [==============================] - ETA: 0s - loss: 0.3480 - accuracy: 0.8918
# Epoch 19: val_loss improved from 0.33246 to 0.32806, saving model to apple_model.h5
# 91/91 [==============================] - 72s 789ms/step - loss: 0.3480 - accuracy: 0.8918 - val_loss: 0.3281 - val_accuracy: 0.9034
# Epoch 20/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2895 - accuracy: 0.8988
# Epoch 20: val_loss did not improve from 0.32806
# 91/91 [==============================] - 71s 785ms/step - loss: 0.2895 - accuracy: 0.8988 - val_loss: 0.3362 - val_accuracy: 0.8750
# Epoch 21/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.9008
# Epoch 21: val_loss improved from 0.32806 to 0.31119, saving model to apple_model.h5
# 91/91 [==============================] - 72s 796ms/step - loss: 0.2888 - accuracy: 0.9008 - val_loss: 0.3112 - val_accuracy: 0.9006
# Epoch 22/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.9043
# Epoch 22: val_loss improved from 0.31119 to 0.30375, saving model to apple_model.h5
# 91/91 [==============================] - 78s 860ms/step - loss: 0.2705 - accuracy: 0.9043 - val_loss: 0.3038 - val_accuracy: 0.9006
# Epoch 23/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2516 - accuracy: 0.9161
# Epoch 23: val_loss improved from 0.30375 to 0.25917, saving model to apple_model.h5
# 91/91 [==============================] - 72s 790ms/step - loss: 0.2516 - accuracy: 0.9161 - val_loss: 0.2592 - val_accuracy: 0.9006
# Epoch 24/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.9161
# Epoch 24: val_loss did not improve from 0.25917
# 91/91 [==============================] - 78s 854ms/step - loss: 0.2316 - accuracy: 0.9161 - val_loss: 0.3399 - val_accuracy: 0.8949
# Epoch 25/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.9119
# Epoch 25: val_loss did not improve from 0.25917
# 91/91 [==============================] - 71s 784ms/step - loss: 0.2494 - accuracy: 0.9119 - val_loss: 0.3092 - val_accuracy: 0.8778
# Epoch 26/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.9223
# Epoch 26: val_loss improved from 0.25917 to 0.21536, saving model to apple_model.h5
# 91/91 [==============================] - 71s 784ms/step - loss: 0.2469 - accuracy: 0.9223 - val_loss: 0.2154 - val_accuracy: 0.9176
# Epoch 27/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2072 - accuracy: 0.9265
# Epoch 27: val_loss did not improve from 0.21536
# 91/91 [==============================] - 72s 788ms/step - loss: 0.2072 - accuracy: 0.9265 - val_loss: 0.3122 - val_accuracy: 0.9091
# Epoch 28/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9307
# Epoch 28: val_loss did not improve from 0.21536
# 91/91 [==============================] - 72s 791ms/step - loss: 0.2220 - accuracy: 0.9307 - val_loss: 0.2692 - val_accuracy: 0.9148
# Epoch 29/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2095 - accuracy: 0.9320
# Epoch 29: val_loss did not improve from 0.21536
# 91/91 [==============================] - 71s 786ms/step - loss: 0.2095 - accuracy: 0.9320 - val_loss: 0.3277 - val_accuracy: 0.8892
# Epoch 30/30
# 91/91 [==============================] - ETA: 0s - loss: 0.2319 - accuracy: 0.9265
# Epoch 30: val_loss did not improve from 0.21536
# 91/91 [==============================] - 72s 790ms/step - loss: 0.2319 - accuracy: 0.9265 - val_loss: 0.3068 - val_accuracy: 0.9034

# %% [markdown]
# # Model Evaluation

# %%
train_acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']
epochs = range(1,31)
plt.plot(epochs,train_acc,'g',label='Training Accuracy')
plt.plot(epochs,val_acc,'b',label='Validation Accuracy')
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
train_loss=model_history.history['loss']
val_loss=model_history.history['val_loss']
epochs=range(1,31)
plt.plot(epochs,train_loss,'g',label='Training Loss')
plt.plot(epochs,val_loss,'b',label='Validation Loss')
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Model Prediction

# %%
# get the image
test_img = '/content/test/Test_0.jpg'
img_pred = Image.open(test_img) 
from tensorflow.keras.preprocessing import image
test_img=image.load_img(test_img,target_size=(224,224))
test_img=image.img_to_array(test_img)
test_img=test_img/255
test_img=np.expand_dims(test_img,axis=0)
result=model.predict(test_img)
print(np.argmax(result))

Categories=['healthy','multiple_disease','rust','scab']
image_result=plt.imshow(img_pred)
plt.title(Categories[np.argmax(result)])
plt.show()
# Out:
# 2

# %% [markdown]
# #Save Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tf.keras.models.save_model(model,'/content/gdrive/MyDrive/apple_model.h5')
